# %% [markdown]
# # Hypothesis Testing Chi2 Test (Athletes and Smokers)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
from scipy.stats import chi2_contingency

# %% [raw]
# Assume Null Hypothesis as Ho: Independence of categorical variables (Athlete and Smoking not related)
# Thus Alternate Hypothesis as Ha: Dependence of categorical variables (Athlete and Smoking is somewhat/significantly related)

# %%
# Make 2-dimensional array
obs=np.array([[14,4],[0,10]])
obs
# Out:
# array([[14,  4],
#        [ 0, 10]])

# %%
# Chi2 contengency independence test
chi2_contingency(obs) # o/p is (Chi2 stats value, p_value, df, expected obsvations)
# Out:
# (12.600000000000001,
#  0.0003857467556820071,
#  1,
#  array([[9., 9.],
#         [5., 5.]]))

# %%
# Or 
stats, p, df, exp = chi2_contingency(obs) 
print('p_value =',p)
# Out:
# p_value = 0.0003857467556820071

# %%
# Compare p_value with α = 0.05

# %% [raw]
# As (p_value = 0.00038) < (α = 0.05); Reject Null Hypothesis
# i.e. Dependence among categorical variables
# Thus Athlete and Smoking is somewhat/significantly related
